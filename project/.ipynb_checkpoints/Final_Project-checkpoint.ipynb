# %%
# %matplotlib inline
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import sys
sys.path.append("..") # Adds higher directory to python modules path.  
import seaborn as sns
import os.path
from scipy.stats import ttest_ind
import missingno as msno

# %% [raw]
# pd.set_option('display.max_rows', None)

# %% [markdown]
# fixing datatype issues in the sources

# %% [raw]
# ClientsCancellation = pd.read_csv('./ProjectData/Client Cancellations0.csv')

# %% [raw]
# #The date data is not valid, it needs to be fixed
# ClientsCancellation["Cancel Date"] = pd.to_datetime(ClientsCancellation["Cancel Date"], format="%m/%d/%Y")
# ClientsCancellation["Booking Date"] = pd.to_datetime(ClientsCancellation["Booking Date"], format="%m/%d/%Y")

# %% [raw]
# ClientsCancellation.to_csv ('ProjectData/ClientsCancellation1.csv')

# %% [raw]
# NoShowReport0 = pd.read_csv('./ProjectData/No-Show Report0.csv')

# %% [raw]
# #The date data is not valid, it needs to be fixed
# NoShowReport0["Date"] = pd.to_datetime(NoShowReport0["Date"], format="%m/%d/%Y")

# %% [raw]
# NoShowReport0.to_csv ('ProjectData/NoShowReport1.csv')

# %% [raw]
# ReceiptTransactions0 = pd.read_csv('./ProjectData/Receipt Transactions0.csv')

# %% [raw]
# #The date data is not valid, it needs to be fixed
# ReceiptTransactions0["Date"] = pd.to_datetime(ReceiptTransactions0["Date"], format="%m/%d/%Y")

# %% [raw]
# ReceiptTransactions0.to_csv ('ProjectData/ReceiptTransactions1.csv')

# %% [markdown]
# # Importing the flat file

# %%
conn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=DESKTOP-PFMG0IP\SQLEXPRESS;"
                      "Database=NoShow;"
                      "Trusted_Connection=yes;")

# %%
# check if file exists
if os.path.exists('NoShow_ff.csv'):
    NoShow_ff = pd.read_csv('NoShow_ff.csv',index_col=0)
else:
    # Get the V_ff table
    NoShow_ff = pd.read_sql("SELECT * FROM V_ff;",conn)
    # save to csv
    NoShow_ff.to_csv('NoShow_ff.csv')

# %%
NoShow_ff.describe(include='all')
# Out:
#              Date_CD         Year  Season      WeekEnd     LastYear  \
# count   2.764000e+03  2764.000000    2764  2764.000000  1942.000000
# unique           NaN          NaN       4          NaN          NaN
# top              NaN          NaN  Summer          NaN          NaN
# freq             NaN          NaN    1323          NaN          NaN
# mean    2.018064e+07  2018.000724     NaN     0.438495  2018.000515
# std     3.418682e+02     0.026895     NaN     0.496292     0.022692
# min     2.018010e+07  2018.000000     NaN     0.000000  2018.000000
# 25%     2.018052e+07  2018.000000     NaN     0.000000  2018.000000
# 50%     2.018062e+07  2018.000000     NaN     0.000000  2018.000000
# 75%     2.018072e+07  2018.000000     NaN     1.000000  2018.000000
# max     2.019040e+07  2019.000000     NaN     1.000000  2019.000000
#
#        LastSeason  LastWeekEnd        Date    LastDate  DaysRecency  ...  \
# count        1942  1942.000000        2764        1942  1942.000000  ...
# unique          4          NaN         178         164          NaN  ...
# top        Summer          NaN  2018-06-30  2018-06-30          NaN  ...
# freq          907          NaN          66          56          NaN  ...
# mean          NaN     0.432029         NaN         NaN    27.842430  ...
# std           NaN     0.495486         NaN         NaN    41.569045  ...
# min           NaN     0.000000         NaN         NaN     0.000000  ...
# 25%           NaN     0.000000         NaN         NaN     0.000000  ...
# 50%           NaN     0.000000         NaN         NaN     8.000000  ...
# 75%           NaN     1.000000         NaN         NaN    40.000000  ...
# max           NaN     1.000000         NaN         NaN   260.000000  ...
#
#          CancelDay CancelWeekday CanceledBy        Days LastIsCanceled  \
# count   389.000000    389.000000        360  377.000000    1942.000000
# unique         NaN           NaN          7         NaN            NaN
# top            NaN           NaN         JJ         NaN            NaN
# freq           NaN           NaN        141         NaN            NaN
# mean     15.696658      4.514139        NaN    5.952255       0.161174
# std       8.846661      1.565719        NaN   11.708464       0.367786
# min       1.000000      1.000000        NaN  -37.000000       0.000000
# 25%       8.000000      3.000000        NaN    0.000000       0.000000
# 50%      17.000000      5.000000        NaN    2.000000       0.000000
# 75%      24.000000      6.000000        NaN    7.000000       0.000000
# max      31.000000      7.000000        NaN   66.000000       1.000000
#
#        LastCanceledBy LastCancelWeekday TotalClientCancellationsTillNow  \
# count             288        313.000000                     1942.000000
# unique              7               NaN                             NaN
# top                JJ               NaN                             NaN
# freq              126               NaN                             NaN
# mean              NaN          4.338658                        1.247168
# std               NaN          1.533914                        2.656281
# min               NaN          1.000000                        0.000000
# 25%               NaN          3.000000                        0.000000
# 50%               NaN          4.000000                        0.000000
# 75%               NaN          5.000000                        1.000000
# max               NaN          7.000000                       22.000000
#
#        TotalClientBookingsTillNow  CancellationPcnt
# count                 2764.000000       1942.000000
# unique                        NaN               NaN
# top                           NaN               NaN
# freq                          NaN               NaN
# mean                     4.645441          0.134367
# std                      6.781757          0.235189
# min                      0.000000          0.000000
# 25%                      0.000000          0.000000
# 50%                      2.000000          0.000000
# 75%                      6.000000          0.214286
# max                     43.000000          1.000000
#
# [11 rows x 45 columns]

# %%
NoShow_ff.dtypes
# Out:
# Date_CD                              int64
# Year                                 int64
# Season                              object
# WeekEnd                              int64
# LastYear                           float64
# LastSeason                          object
# LastWeekEnd                        float64
# Date                                object
# LastDate                            object
# DaysRecency                        float64
# ClientType                          object
# Staff                               object
# BLastStaff                          object
# RTLastStaff                         object
# StaffCancType                       object
# BLastServiceCode                    object
# BLastWomenMenService                object
# BLastColorCutService                object
# LastServiceCategory                 object
# LastServicePrice                   float64
# LastServiceCost                    float64
# ServiceCode                         object
# ServiceCancType                     object
# WomenMenService                     object
# ColorCutService                     object
# ServiceCategory                     object
# ServicePrice                         int64
# ServiceCost                          int64
# RTLastWomenMen                      object
# RTLastColorCutReciept               object
# LastTotalAmount                    float64
# LastTotalGST                       float64
# LastTotalPST                       float64
# WasProdPerch                       float64
# IsCanceled                           int64
# CancelDay                          float64
# CancelWeekday                      float64
# CanceledBy                          object
# Days                               float64
# LastIsCanceled                     float64
# LastCanceledBy                      object
# LastCancelWeekday                  float64
# TotalClientCancellationsTillNow    float64
# TotalClientBookingsTillNow           int64
# CancellationPcnt                   float64
# dtype: object

# %% [markdown]
# # Converting variables

# %%
category_cols = ['Year','Season', 'WeekEnd','LastYear','LastSeason','LastWeekEnd',
                'ClientType','Staff','StaffCancType','BLastStaff','RTLastStaff',
                'BLastServiceCode','BLastWomenMenService','BLastColorCutService','LastServiceCategory',
                'ServiceCode','WomenMenService','ColorCutService','ServiceCategory','ServiceCancType',
                'RTLastWomenMen','RTLastColorCutReciept','WasProdPerch',
                'IsCanceled','CancelDay','CancelWeekday','CanceledBy','LastIsCanceled','LastCanceledBy',
                'LastCancelWeekday']

numeric_cols = ['LastServicePrice','LastServiceCost','ServicePrice','ServiceCost',
                'LastTotalAmount','LastTotalGST','LastTotalPST','Days', 'DaysRecency',
                'TotalClientCancellationsTillNow','TotalClientBookingsTillNow','CancellationPcnt']

# %%
for col,val in NoShow_ff.items():
    if col in category_cols:
        NoShow_ff[col]= NoShow_ff[col].astype('category')
    if col in numeric_cols:
        NoShow_ff[col]= NoShow_ff[col].astype('float64')

# %%
NoShow_ff.dtypes
# Out:
# Date_CD                               int64
# Year                               category
# Season                             category
# WeekEnd                            category
# LastYear                           category
# LastSeason                         category
# LastWeekEnd                        category
# Date                                 object
# LastDate                             object
# DaysRecency                         float64
# ClientType                         category
# Staff                              category
# BLastStaff                         category
# RTLastStaff                        category
# StaffCancType                      category
# BLastServiceCode                   category
# BLastWomenMenService               category
# BLastColorCutService               category
# LastServiceCategory                category
# LastServicePrice                    float64
# LastServiceCost                     float64
# ServiceCode                        category
# ServiceCancType                    category
# WomenMenService                    category
# ColorCutService                    category
# ServiceCategory                    category
# ServicePrice                        float64
# ServiceCost                         float64
# RTLastWomenMen                     category
# RTLastColorCutReciept              category
# LastTotalAmount                     float64
# LastTotalGST                        float64
# LastTotalPST                        float64
# WasProdPerch                       category
# IsCanceled                         category
# CancelDay                          category
# CancelWeekday                      category
# CanceledBy                         category
# Days                                float64
# LastIsCanceled                     category
# LastCanceledBy                     category
# LastCancelWeekday                  category
# TotalClientCancellationsTillNow     float64
# TotalClientBookingsTillNow          float64
# CancellationPcnt                    float64
# dtype: object

# %% [markdown]
# ### Some variables which cause leakage:"Days","CancelDay","CancelWeekday","CanceledBy"
# ### We also replaced the dates with categories of their parts.

# %%
drop_list = ["Days","CancelDay","CancelWeekday","CanceledBy","Date_CD","Date","LastDate"]

# %%
NoShow_f= NoShow_ff.drop(drop_list, axis=1)

# %%
pd.set_option('display.max_columns', None)
NoShow_f.describe(include='all')
# Out:
#           Year  Season  WeekEnd  LastYear LastSeason  LastWeekEnd  \
# count   2764.0    2764   2764.0    1942.0       1942       1942.0
# unique     2.0       4      2.0       2.0          4          2.0
# top     2018.0  Summer      0.0    2018.0     Summer          0.0
# freq    2762.0    1323   1552.0    1941.0        907       1103.0
# mean       NaN     NaN      NaN       NaN        NaN          NaN
# std        NaN     NaN      NaN       NaN        NaN          NaN
# min        NaN     NaN      NaN       NaN        NaN          NaN
# 25%        NaN     NaN      NaN       NaN        NaN          NaN
# 50%        NaN     NaN      NaN       NaN        NaN          NaN
# 75%        NaN     NaN      NaN       NaN        NaN          NaN
# max        NaN     NaN      NaN       NaN        NaN          NaN
#
#         DaysRecency     ClientType Staff BLastStaff RTLastStaff  \
# count   1942.000000           2764  2764       1942         789
# unique          NaN              3     7          7           7
# top             NaN  LowCancClient    JJ         JJ          JJ
# freq            NaN           2181   915        637         297
# mean      27.842430            NaN   NaN        NaN         NaN
# std       41.569045            NaN   NaN        NaN         NaN
# min        0.000000            NaN   NaN        NaN         NaN
# 25%        0.000000            NaN   NaN        NaN         NaN
# 50%        8.000000            NaN   NaN        NaN         NaN
# 75%       40.000000            NaN   NaN        NaN         NaN
# max      260.000000            NaN   NaN        NaN         NaN
#
#         StaffCancType BLastServiceCode BLastWomenMenService  \
# count            2764             1942                 1942
# unique              2               27                    4
# top     HighCancStaff             SHCW                Other
# freq             2471              552                 1011
# mean              NaN              NaN                  NaN
# std               NaN              NaN                  NaN
# min               NaN              NaN                  NaN
# 25%               NaN              NaN                  NaN
# 50%               NaN              NaN                  NaN
# 75%               NaN              NaN                  NaN
# max               NaN              NaN                  NaN
#
#        BLastColorCutService LastServiceCategory  LastServicePrice  \
# count                  1942                1942       1942.000000
# unique                    3                   3               NaN
# top                     Cut               STYLE               NaN
# freq                    874                1318               NaN
# mean                    NaN                 NaN         30.802266
# std                     NaN                 NaN         46.525636
# min                     NaN                 NaN          0.000000
# 25%                     NaN                 NaN          0.000000
# 50%                     NaN                 NaN          0.000000
# 75%                     NaN                 NaN        102.000000
# max                     NaN                 NaN        300.000000
#
#         LastServiceCost ServiceCode  ServiceCancType WomenMenService  \
# count       1942.000000        2764             2764            2764
# unique              NaN          29                3               4
# top                 NaN        SHCW  HighCancService           Other
# freq                NaN         929             2431            1252
# mean           6.251287         NaN              NaN             NaN
# std            2.588901         NaN              NaN             NaN
# min            0.000000         NaN              NaN             NaN
# 25%            5.000000         NaN              NaN             NaN
# 50%            5.000000         NaN              NaN             NaN
# 75%           10.000000         NaN              NaN             NaN
# max           10.000000         NaN              NaN             NaN
#
#        ColorCutService ServiceCategory  ServicePrice  ServiceCost  \
# count             2764            2764   2764.000000  2764.000000
# unique               3               3           NaN          NaN
# top                Cut           STYLE           NaN          NaN
# freq              1436            1998           NaN          NaN
# mean               NaN             NaN     36.358538     6.000362
# std                NaN             NaN     48.882346     2.502912
# min                NaN             NaN      0.000000     0.000000
# 25%                NaN             NaN      0.000000     5.000000
# 50%                NaN             NaN      0.000000     5.000000
# 75%                NaN             NaN    102.000000     5.000000
# max                NaN             NaN    300.000000    10.000000
#
#        RTLastWomenMen RTLastColorCutReciept  LastTotalAmount  LastTotalGST  \
# count             789                   789       789.000000    789.000000
# unique              3                     3              NaN           NaN
# top             Other                   Cut              NaN           NaN
# freq              368                   397              NaN           NaN
# mean              NaN                   NaN        91.003802      9.808670
# std               NaN                   NaN        68.739568      8.275474
# min               NaN                   NaN         0.000000      0.000000
# 25%               NaN                   NaN        50.000000      3.750000
# 50%               NaN                   NaN        70.000000      8.000000
# 75%               NaN                   NaN       122.000000     12.940000
# max               NaN                   NaN       350.000000     47.050000
#
#         LastTotalPST  IsCanceled  LastIsCanceled LastCanceledBy  \
# count     789.000000      2764.0          1942.0            288
# unique           NaN         2.0             2.0              7
# top              NaN         0.0             0.0             JJ
# freq             NaN      2375.0          1629.0            126
# mean       15.693872         NaN             NaN            NaN
# std        13.240758         NaN             NaN            NaN
# min         0.000000         NaN             NaN            NaN
# 25%         6.000000         NaN             NaN            NaN
# 50%        12.800000         NaN             NaN            NaN
# 75%        20.704000         NaN             NaN            NaN
# max        75.280000         NaN             NaN            NaN
#
#         LastCancelWeekday  TotalClientCancellationsTillNow  \
# count               313.0                      1942.000000
# unique                7.0                              NaN
# top                   3.0                              NaN
# freq                100.0                              NaN
# mean                  NaN                         1.247168
# std                   NaN                         2.656281
# min                   NaN                         0.000000
# 25%                   NaN                         0.000000
# 50%                   NaN                         0.000000
# 75%                   NaN                         1.000000
# max                   NaN                        22.000000
#
#         TotalClientBookingsTillNow  CancellationPcnt
# count                  2764.000000       1942.000000
# unique                         NaN               NaN
# top                            NaN               NaN
# freq                           NaN               NaN
# mean                      4.645441          0.134367
# std                       6.781757          0.235189
# min                       0.000000          0.000000
# 25%                       0.000000          0.000000
# 50%                       2.000000          0.000000
# 75%                       6.000000          0.214286
# max                      43.000000          1.000000

# %%
NoShow_f.head()
# Out:
#    Year  Season WeekEnd LastYear LastSeason LastWeekEnd  DaysRecency  \
# 0  2018  Summer       1   2018.0     Summer         1.0          0.0
# 1  2018  Summer       1   2018.0     Summer         1.0          0.0
# 2  2018  Summer       1      NaN        NaN         NaN          NaN
# 3  2018  Summer       0   2018.0     Summer         0.0          0.0
# 4  2018  Summer       0   2018.0     Summer         0.0          0.0
#
#       ClientType   Staff BLastStaff RTLastStaff  StaffCancType  \
# 0  LowCancClient  JOANNE     JOANNE         NaN  HighCancStaff
# 1  LowCancClient  JOANNE      BECKY         NaN  HighCancStaff
# 2  LowCancClient  JOANNE        NaN      JOANNE  HighCancStaff
# 3  LowCancClient  JOANNE         JJ          JJ  HighCancStaff
# 4  LowCancClient  JOANNE     JOANNE          JJ  HighCancStaff
#
#   BLastServiceCode BLastWomenMenService BLastColorCutService  \
# 0              CAL                Other                Other
# 1             SHCW                Woman                  Cut
# 2              NaN                  NaN                  NaN
# 3             SHCW                Woman                  Cut
# 4              CAL                Other                Other
#
#   LastServiceCategory  LastServicePrice  LastServiceCost ServiceCode  \
# 0               COLOR               0.0             10.0         CAL
# 1               STYLE             102.0              5.0         CAL
# 2                 NaN               NaN              NaN         CAL
# 3               STYLE             102.0              5.0         CAL
# 4               COLOR               0.0             10.0         CAL
#
#   ServiceCancType WomenMenService ColorCutService ServiceCategory  \
# 0  LowCancService           Other           Other           COLOR
# 1  LowCancService           Other           Other           COLOR
# 2  LowCancService           Other           Other           COLOR
# 3  LowCancService           Other           Other           COLOR
# 4  LowCancService           Other           Other           COLOR
#
#    ServicePrice  ServiceCost RTLastWomenMen RTLastColorCutReciept  \
# 0           0.0         10.0            NaN                   NaN
# 1           0.0         10.0            NaN                   NaN
# 2           0.0         10.0          Other                 Color
# 3           0.0         10.0          Woman                   Cut
# 4           0.0         10.0          Woman                   Cut
#
#    LastTotalAmount  LastTotalGST  LastTotalPST IsCanceled LastIsCanceled  \
# 0              NaN           NaN           NaN          0            0.0
# 1              NaN           NaN           NaN          0            0.0
# 2             50.0           2.5          4.00          0            NaN
# 3            102.0           5.1          8.16          0            0.0
# 4            102.0           5.1          8.16          0            0.0
#
#   LastCanceledBy LastCancelWeekday  TotalClientCancellationsTillNow  \
# 0            NaN               NaN                              0.0
# 1            NaN               NaN                              0.0
# 2            NaN               NaN                              NaN
# 3            NaN               NaN                              0.0
# 4            NaN               NaN                              0.0
#
#    TotalClientBookingsTillNow  CancellationPcnt
# 0                         7.0               0.0
# 1                         5.0               0.0
# 2                         0.0               NaN
# 3                         3.0               0.0
# 4                         4.0               0.0

# %% [markdown]
# # EDA

# %%
#Storing the label column name
label = 'IsCanceled'
#Create a list for columns with more than 5% and less than 50% missing
high_miss_cols = []
#Create a list for columns with more than 50% missing
very_high_miss_cols = []
#Create a list for columns with less or equal to 5% missing 
low_miss_cols = []
#Creating all the plots
np.set_printoptions(precision=3, suppress=True) #precision settings
sns.countplot(data=NoShow_f , x=label)
plt.show()

# %%
for column in NoShow_f.columns:
    var = NoShow_f[column]
    print (f'{column} Type: {var.dtype}')
    missing = var.isna().sum()
    total = len(var)
    if missing/total > 0.05 and missing/total <= 0.5:
        high_miss_cols.append(column)
    if missing/total <= 0.05:
        low_miss_cols.append(column)
    if missing/total > 0.5:
        very_high_miss_cols.append(column)
    print (f'Missing: {missing} ({missing/total*100}%)')
    if str(var.dtype) != 'category':
        mean = np.mean(var)
        median = np.median(var.dropna())
        std = np.std(var)
        minimum = np.min(var)
        maximum = np.max(var)
        print (f'Mean: {mean} (Std: {std})')
        print (f'Median: {median} ')
        print (f'Min: {minimum} Max: {maximum}')
        sns.distplot(var.dropna())
        plt.show()
        sns.boxplot(data=NoShow_f,x=label, y=column, orient="v")
        plt.show()
    else:
        sns.catplot(y=column, data=NoShow_f, hue=label, kind="count")
        plt.show()
# Out:
# Year Type: category
# Missing: 0 (0.0%)
# Season Type: category
# Missing: 0 (0.0%)
# WeekEnd Type: category
# Missing: 0 (0.0%)
# LastYear Type: category
# Missing: 822 (29.739507959479017%)
# LastSeason Type: category
# Missing: 822 (29.739507959479017%)
# LastWeekEnd Type: category
# Missing: 822 (29.739507959479017%)
# DaysRecency Type: float64
# Missing: 822 (29.739507959479017%)
# Mean: 27.842430484037074 (Std: 41.5583405128668)
# Median: 8.0
# Min: 0.0 Max: 260.0
# ClientType Type: category
# Missing: 0 (0.0%)
# Staff Type: category
# Missing: 0 (0.0%)
# BLastStaff Type: category
# Missing: 822 (29.739507959479017%)
# RTLastStaff Type: category
# Missing: 1975 (71.45441389290883%)
# StaffCancType Type: category
# Missing: 0 (0.0%)
# BLastServiceCode Type: category
# Missing: 822 (29.739507959479017%)
# BLastWomenMenService Type: category
# Missing: 822 (29.739507959479017%)
# BLastColorCutService Type: category
# Missing: 822 (29.739507959479017%)
# LastServiceCategory Type: category
# Missing: 822 (29.739507959479017%)
# LastServicePrice Type: float64
# Missing: 822 (29.739507959479017%)
# Mean: 30.80226570545829 (Std: 46.5136551826508)
# Median: 0.0
# Min: 0.0 Max: 300.0
# LastServiceCost Type: float64
# Missing: 822 (29.739507959479017%)
# Mean: 6.251287332646756 (Std: 2.5882340704292632)
# Median: 5.0
# Min: 0.0 Max: 10.0
# ServiceCode Type: category
# Missing: 0 (0.0%)
# ServiceCancType Type: category
# Missing: 0 (0.0%)
# WomenMenService Type: category
# Missing: 0 (0.0%)
# ColorCutService Type: category
# Missing: 0 (0.0%)
# ServiceCategory Type: category
# Missing: 0 (0.0%)
# ServicePrice Type: float64
# Missing: 0 (0.0%)
# Mean: 36.358538350217074 (Std: 48.87350283624534)
# Median: 0.0
# Min: 0.0 Max: 300.0
# ServiceCost Type: float64
# Missing: 0 (0.0%)
# Mean: 6.000361794500724 (Std: 2.5024589671220525)
# Median: 5.0
# Min: 0.0 Max: 10.0
# RTLastWomenMen Type: category
# Missing: 1975 (71.45441389290883%)
# RTLastColorCutReciept Type: category
# Missing: 1975 (71.45441389290883%)
# LastTotalAmount Type: float64
# Missing: 1975 (71.45441389290883%)
# Mean: 91.00380228136882 (Std: 68.69599262348707)
# Median: 70.0
# Min: 0.0 Max: 350.0
# LastTotalGST Type: float64
# Missing: 1975 (71.45441389290883%)
# Mean: 9.808669835234493 (Std: 8.27022769043502)
# Median: 8.0
# Min: 0.0 Max: 47.05
# LastTotalPST Type: float64
# Missing: 1975 (71.45441389290883%)
# Mean: 15.693871736375156 (Std: 13.232364304696002)
# Median: 12.8
# Min: 0.0 Max: 75.28
# IsCanceled Type: category
# Missing: 0 (0.0%)
# LastIsCanceled Type: category
# Missing: 822 (29.739507959479017%)
# LastCanceledBy Type: category
# Missing: 2476 (89.58031837916064%)
# LastCancelWeekday Type: category
# Missing: 2451 (88.67583212735167%)
# TotalClientCancellationsTillNow Type: float64
# Missing: 822 (29.739507959479017%)
# Mean: 1.247167868177137 (Std: 2.655596602998157)
# Median: 0.0
# Min: 0.0 Max: 22.0
# TotalClientBookingsTillNow Type: float64
# Missing: 0 (0.0%)
# Mean: 4.645441389290883 (Std: 6.7805302633182345)
# Median: 2.0
# Min: 0.0 Max: 43.0
# CancellationPcnt Type: float64
# Missing: 822 (29.739507959479017%)
# Mean: 0.13436713084817084 (Std: 0.23512827426674604)
# Median: 0.0
# Min: 0.0 Max: 1.0

# %% [markdown]
# # Correlation matrix

# %%
# convert the label for the correlation matrix
NoShow_f["IsCanceled_int"]= NoShow_f[label].astype('int')

# %%
# calculate the correlation matrix - 
corr = NoShow_f.corr(method = 'spearman')
pd.set_option('display.max_columns', None)
corr
# Out:
#                                  DaysRecency  LastServicePrice  \
# DaysRecency                         1.000000          0.065222
# LastServicePrice                    0.065222          1.000000
# LastServiceCost                    -0.259312         -0.288334
# ServicePrice                        0.149234          0.365413
# ServiceCost                        -0.389584          0.023383
# LastTotalAmount                    -0.083818          0.263551
# LastTotalGST                       -0.239720          0.003221
# LastTotalPST                       -0.239720          0.003221
# TotalClientCancellationsTillNow    -0.198299         -0.138927
# TotalClientBookingsTillNow         -0.287250         -0.190297
# CancellationPcnt                   -0.171556         -0.104682
# IsCanceled_int                     -0.147090         -0.019536
#
#                                  LastServiceCost  ServicePrice  ServiceCost  \
# DaysRecency                            -0.259312      0.149234    -0.389584
# LastServicePrice                       -0.288334      0.365413     0.023383
# LastServiceCost                         1.000000      0.020343     0.343949
# ServicePrice                            0.020343      1.000000    -0.267243
# ServiceCost                             0.343949     -0.267243     1.000000
# LastTotalAmount                         0.230646      0.209375     0.206208
# LastTotalGST                            0.135962     -0.027773     0.085340
# LastTotalPST                            0.135962     -0.027773     0.085340
# TotalClientCancellationsTillNow         0.006315     -0.123835    -0.022091
# TotalClientBookingsTillNow              0.134932     -0.250214     0.176779
# CancellationPcnt                        0.003328     -0.078133    -0.025535
# IsCanceled_int                         -0.004569     -0.074985     0.027625
#
#                                  LastTotalAmount  LastTotalGST  LastTotalPST  \
# DaysRecency                            -0.083818     -0.239720     -0.239720
# LastServicePrice                        0.263551      0.003221      0.003221
# LastServiceCost                         0.230646      0.135962      0.135962
# ServicePrice                            0.209375     -0.027773     -0.027773
# ServiceCost                             0.206208      0.085340      0.085340
# LastTotalAmount                         1.000000      0.410714      0.410714
# LastTotalGST                            0.410714      1.000000      1.000000
# LastTotalPST                            0.410714      1.000000      1.000000
# TotalClientCancellationsTillNow        -0.147829     -0.011923     -0.011923
# TotalClientBookingsTillNow              0.061578      0.278020      0.278020
# CancellationPcnt                       -0.122335     -0.025305     -0.025305
# IsCanceled_int                         -0.018031     -0.070163     -0.070163
#
#                                  TotalClientCancellationsTillNow  \
# DaysRecency                                            -0.198299
# LastServicePrice                                       -0.138927
# LastServiceCost                                         0.006315
# ServicePrice                                           -0.123835
# ServiceCost                                            -0.022091
# LastTotalAmount                                        -0.147829
# LastTotalGST                                           -0.011923
# LastTotalPST                                           -0.011923
# TotalClientCancellationsTillNow                         1.000000
# TotalClientBookingsTillNow                              0.605061
# CancellationPcnt                                        0.950493
# IsCanceled_int                                          0.238034
#
#                                  TotalClientBookingsTillNow  CancellationPcnt  \
# DaysRecency                                       -0.287250         -0.171556
# LastServicePrice                                  -0.190297         -0.104682
# LastServiceCost                                    0.134932          0.003328
# ServicePrice                                      -0.250214         -0.078133
# ServiceCost                                        0.176779         -0.025535
# LastTotalAmount                                    0.061578         -0.122335
# LastTotalGST                                       0.278020         -0.025305
# LastTotalPST                                       0.278020         -0.025305
# TotalClientCancellationsTillNow                    0.605061          0.950493
# TotalClientBookingsTillNow                         1.000000          0.447369
# CancellationPcnt                                   0.447369          1.000000
# IsCanceled_int                                     0.157828          0.261133
#
#                                  IsCanceled_int
# DaysRecency                           -0.147090
# LastServicePrice                      -0.019536
# LastServiceCost                       -0.004569
# ServicePrice                          -0.074985
# ServiceCost                            0.027625
# LastTotalAmount                       -0.018031
# LastTotalGST                          -0.070163
# LastTotalPST                          -0.070163
# TotalClientCancellationsTillNow        0.238034
# TotalClientBookingsTillNow             0.157828
# CancellationPcnt                       0.261133
# IsCanceled_int                         1.000000

# %%
# plot the heatmap
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,linewidths=.5, ax=ax, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
NoShow_f = NoShow_f.drop("IsCanceled_int", axis=1)

# %% [markdown]
# ### There is a high correlation between "TotalClientCancellationsTillNow","TotalClientBookingsTillNow" and "CancellationPcnt"."CancellationPcnt", "TotalClientCancellationsTillNow" have the higher correlation with our target.

# %% [markdown]
# # Outliers

# %%
def is_outlier (series,iqr_const=3):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    return np.abs(series-series.median())>(iqr_const*iqr)

# %%
cols_with_outliers = []
for column in NoShow_f.columns:
    var = NoShow_f[column].dropna()
    if str(var.dtype) != 'category':
        sum_outlier = is_outlier(var).sum()
        #print(f'sum : {sum_outlier}')
        if sum_outlier>1:
            cols_with_outliers.append(column)

# %%
# This is the list of columns that have outliers
cols_with_outliers
# Out:
# ['DaysRecency',
#  'ServiceCost',
#  'LastTotalAmount',
#  'LastTotalGST',
#  'LastTotalPST',
#  'TotalClientCancellationsTillNow',
#  'TotalClientBookingsTillNow',
#  'CancellationPcnt']

# %% [markdown]
# ## First, we will check if the outliers affect the assumptions, using t-test:

# %%
#for 'cols_with_outliers', we check the significance of the difference in distributions between with and without outliers.
#only columns with significant diffenerce will be included in the list 'ttest_signi'.
P_VALUE = 0.045 #threshold for t-test
ttest_signi = []
for column in cols_with_outliers:
    col_data = NoShow_f[column].dropna()
    col_data_no_outliers = col_data[~is_outlier(col_data)]
    print (f'{column}')
    sns.distplot(col_data, hist=True, kde_kws = {'label':'with outliers'})
    sns.distplot(col_data_no_outliers, hist=True, kde_kws = {'label':'without outliers'})
    plt.show()
    t, p = ttest_ind(col_data, col_data_no_outliers, equal_var=True)
    print (f'p-value:{p}\n-------------------------')
    if p < P_VALUE:
        ttest_signi.append(column)
# Out:
# DaysRecency
# p-value:7.780621228842413e-07
# -------------------------
# ServiceCost
# C:\Users\USER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\USER\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# p-value:6.432727472602024e-68
# -------------------------
# LastTotalAmount
# p-value:0.18951967774137873
# -------------------------
# LastTotalGST
# p-value:0.1016587455437131
# -------------------------
# LastTotalPST
# p-value:0.10165874554371482
# -------------------------
# TotalClientCancellationsTillNow
# p-value:9.268046737297527e-29
# -------------------------
# TotalClientBookingsTillNow
# p-value:2.8052214655885795e-13
# -------------------------
# CancellationPcnt
# p-value:5.496463594211076e-10
# -------------------------

# %%
ttest_not_signi = [col for col in cols_with_outliers if col not in ttest_signi]

# %% [markdown]
# ## Create a copy for the cleaning part:

# %%
NoShow = NoShow_f.copy()

# %% [markdown]
# ## These are the variables whose outliers does not affect the assumptions:

# %%
ttest_not_signi
# Out:
# ['LastTotalAmount', 'LastTotalGST', 'LastTotalPST']

# %% [markdown]
# ### In the EDA we saw that these variables have more than 70% of missing, we will probably drop them anyway (in the missing treatment part).

# %% [markdown]
# ## These are the variables whose outliers affect the assumptions:

# %%
ttest_signi
# Out:
# ['DaysRecency',
#  'ServiceCost',
#  'TotalClientCancellationsTillNow',
#  'TotalClientBookingsTillNow',
#  'CancellationPcnt']

# %% [markdown]
# ## For the variables in ttest_signi ,we wil check if the outliers affect the results as well:

# %%
for column in ttest_signi:
    df_col = pd.DataFrame()
    df_col[column] =NoShow_f[column]
    df_col[label] =NoShow_f[label]
    df_col['is outlier'] =is_outlier(NoShow_f[column])
    
    sns.catplot(x=column, y=label, hue='is outlier', data=df_col)
    plt.show()

# %% [markdown]
# ### No variables whose outliers affect both the assumptions and the results were found.

# %% [markdown]
# ### The variables whose outliers affect the assumptions but not the results:
# #### "DaysRecency","TotalClientCancellationsTillNow","TotalClientBookingsTillNow","CancellationPcnt", "ServiceCost"
# #### "DaysRecency","TotalClientCancellationsTillNow" - already contains nearly 30% of NULLs which represent new clients. It will be categorized in the Missingness treatment part.
# #### "CancellationPcnt" - is between 0 and 1. We can see the is_outlier function tagged values => 0.65 as outliers. Seems like we need to use a higher iqr factor for this particular variable to detect outliers.
# #### For all those reasons, we will treat now only outliers of "TotalClientBookingsTillNow", "ServiceCost".

# %%
aff_assum = ["TotalClientBookingsTillNow","ServiceCost"]

# %% [markdown]
# ## Outlier treatment

# %% [markdown]
# #### aff_assum = Treatment: replace with NULL.

# %%
#Replaces outliers with NA
def outlier_replace_wt_null (col, df):
    col_data = df[col].dropna()
    col_data[is_outlier(col_data)]=np.nan
    return col_data

# %%
NoShow[aff_assum] = outlier_replace_wt_null(aff_assum, NoShow)

# %% [markdown]
# #### "CancellationPcnt"

# %%
df_col = pd.DataFrame()
df_col["CancellationPcnt"] =NoShow_f["CancellationPcnt"]
df_col[label] =NoShow_f[label]
df_col['is outlier'] =is_outlier(NoShow_f["CancellationPcnt"],5)
sns.catplot(x="CancellationPcnt", y=label, hue='is outlier', data=df_col)
plt.show()

# %% [markdown]
# # Missing

# %%
msno.matrix(NoShow,figsize=(25,25))

# %%
msno.heatmap(NoShow)

# %% [markdown]
# ## Missing treatment:

# %% [markdown]
# ### The variables can be divided into several groups:
# #### very_high_miss_cols = From the EDA, it's over 70% missing -> Treatment: Drop the variable.
# #### high_miss_cols = 30% missing (same percent for all) - All those variables have MNAR type of missing: if there were no visits in the hair salon for this client, in other words - this is a new client, all those variables are NULL-> Treatment: Categorization.

# %%
NoShow = NoShow.drop(very_high_miss_cols , axis=1)

# %% [markdown]
# #### Those variables will be categorized:

# %%
high_miss_cols
# Out:
# ['LastYear',
#  'LastSeason',
#  'LastWeekEnd',
#  'DaysRecency',
#  'BLastStaff',
#  'BLastServiceCode',
#  'BLastWomenMenService',
#  'BLastColorCutService',
#  'LastServiceCategory',
#  'LastServicePrice',
#  'LastServiceCost',
#  'LastIsCanceled',
#  'TotalClientCancellationsTillNow',
#  'CancellationPcnt']

# %%
[f'col: {col} {NoShow[col].unique()}' for col in high_miss_cols]
# Out:
# ['col: LastYear [2018.0, NaN, 2019.0]\nCategories (2, float64): [2018.0, 2019.0]',
#  'col: LastSeason [Summer, NaN, Winter, Fall, Spring]\nCategories (4, object): [Summer, Winter, Fall, Spring]',
#  'col: LastWeekEnd [1.0, NaN, 0.0]\nCategories (2, float64): [1.0, 0.0]',
#  'col: DaysRecency [  0.  nan  40.  60. 154.  62.  24.  37.  29.   1. 101.  63.   7.  43.\n 161.  35.  71.  28.   6.  36.  58.  55.  34.  11. 153.  69.  75.  70.\n  20.   8.  14.   3.  79.  15.  30.  12.  10.  42.  82. 116. 118.  27.\n  22.  19.   5. 151. 143.  61.   4.   2.  72. 174.  23. 112. 172.  66.\n  13.  18.  96.  17. 113. 132.  16.  54.  88.  21.  48. 135.  94. 128.\n 212.  56.  26.  49.  25.  68.  59. 182.  41.  46.  89.  32. 114. 108.\n  57. 140.  87. 134.   9.  74.  67. 199.  45. 111.  52. 189.  47.  98.\n  50.  77.  33.  73.  80. 125. 124.  76.  85. 106.  90.  38. 119. 136.\n 105.  99. 117.  78.  51. 145. 129.  44. 102. 195. 137.  84.  31. 100.\n 109. 148. 121. 160.  64.  65.  39. 193. 104. 123. 149. 133. 103. 131.\n 147.  95.  83. 185. 260. 138. 179. 144. 120. 223. 188.  93.  92. 141.\n  81.  97. 139. 202. 217.  91. 205. 209. 234. 231. 197.  53. 190. 200.]',
#  'col: BLastStaff [JOANNE, BECKY, NaN, JJ, KELLY, SINEAD, HOUSE, TANYA]\nCategories (7, object): [JOANNE, BECKY, JJ, KELLY, SINEAD, HOUSE, TANYA]',
#  'col: BLastServiceCode [CAL, SHCW, NaN, SHCM, CHLPL, ..., SDUD, TRE 1, FRI, SHCC, CAS]\nLength: 28\nCategories (27, object): [CAL, SHCW, SHCM, CHLPL, ..., TRE 1, FRI, SHCC, CAS]',
#  'col: BLastWomenMenService [Other, Woman, NaN, Man, Child]\nCategories (4, object): [Other, Woman, Man, Child]',
#  'col: BLastColorCutService [Other, Cut, NaN, Color]\nCategories (3, object): [Other, Cut, Color]',
#  'col: LastServiceCategory [COLOR, STYLE, NaN, MISC]\nCategories (3, object): [COLOR, STYLE, MISC]',
#  'col: LastServicePrice [  0. 102.  nan  25.  45. 300.  20.  52.]',
#  'col: LastServiceCost [10.  5. nan  0.]',
#  'col: LastIsCanceled [0.0, NaN, 1.0]\nCategories (2, float64): [0.0, 1.0]',
#  'col: TotalClientCancellationsTillNow [ 0. nan  1.  2.  4.  8.  3. 13. 10.  7.  5. 11. 22. 21. 15.  6.  9. 14.\n 16. 18. 12. 17. 19. 20.]',
#  'col: CancellationPcnt [0.      nan 1.    0.333 0.105 0.667 0.8   0.276 0.136 0.464 0.4   0.318\n 0.263 0.25  0.348 0.423 0.524 0.583 0.5   0.564 0.571 0.2   0.182 0.286\n 0.143 0.417 0.294 0.273 0.37  0.167 0.214 0.375 0.3   0.231 0.111 0.324\n 0.6   0.714 0.154 0.312 0.222 0.429 0.75  0.474 0.538 0.444 0.125 0.1\n 0.367 0.344 0.478 0.438 0.308 0.526 0.071 0.062 0.595 0.512 0.55  0.16\n 0.148 0.36  0.091 0.412 0.391 0.833 0.357 0.304 0.278 0.385 0.44  0.407\n 0.043 0.053 0.048 0.32  0.296 0.067 0.059 0.04  0.188 0.088 0.086 0.094\n 0.267 0.235 0.138 0.133 0.077 0.038 0.042 0.176 0.364 0.455 0.483 0.516\n 0.545 0.211 0.05  0.13  0.12  0.115 0.107 0.103 0.056 0.095 0.393 0.097\n 0.389 0.35  0.471 0.379 0.355 0.158 0.15  0.19  0.174 0.292 0.269 0.259\n 0.531 0.559 0.28  0.258 0.242 0.368 0.083 0.045 0.261 0.24  0.238 0.037\n 0.036 0.345 0.45  0.409 0.458 0.537 0.579 0.323 0.118]']

# %%
for column in high_miss_cols:
    var = NoShow[column]
    if str(var.dtype) == 'category':
        var.cat.add_categories(['NewClient'], inplace=True)
        var.fillna('NewClient', inplace=True)
    else:
        num_of_cat = 5
        bins = np.unique([np.quantile(var.dropna(),quantile/num_of_cat) for quantile in range(0,num_of_cat+1)])
        categories = [f'{bins[index]:.2f}-{bins[index+1]:.2f}' for index in range(0,len(bins)-1)]
        NoShow[f'{column}_cat'] = pd.cut(NoShow[column], bins, labels=categories).astype('category')
        NoShow[f'{column}_cat'].cat.add_categories(['NewClient'], inplace=True)
        NoShow[f'{column}_cat'].fillna('NewClient', inplace=True)
        NoShow.drop(column, inplace=True, axis=1)

# %%
NoShow.head(20)
# Out:
#     Year  Season WeekEnd   LastYear LastSeason LastWeekEnd        ClientType  \
# 0   2018  Summer       1       2018     Summer           1     LowCancClient
# 1   2018  Summer       1       2018     Summer           1     LowCancClient
# 2   2018  Summer       1  NewClient  NewClient   NewClient     LowCancClient
# 3   2018  Summer       0       2018     Summer           0     LowCancClient
# 4   2018  Summer       0       2018     Summer           0     LowCancClient
# 5   2018  Winter       1       2018     Winter           1     LowCancClient
# 6   2018  Winter       1       2018     Winter           1     LowCancClient
# 7   2018  Summer       1       2018     Summer           1     LowCancClient
# 8   2018  Summer       1       2018     Summer           1     LowCancClient
# 9   2018  Summer       0       2018     Summer           1  MediumCancClient
# 10  2018    Fall       1       2018     Summer           0  MediumCancClient
# 11  2018    Fall       1       2018       Fall           1     LowCancClient
# 12  2018    Fall       1       2018       Fall           1     LowCancClient
# 13  2018  Spring       0       2018     Spring           0     LowCancClient
# 14  2018  Spring       0       2018     Spring           0     LowCancClient
# 15  2018  Winter       1       2018     Summer           1     LowCancClient
# 16  2018  Spring       0       2018     Spring           0     LowCancClient
# 17  2018  Spring       0       2018     Spring           0     LowCancClient
# 18  2018  Summer       0       2018     Summer           0     LowCancClient
# 19  2018  Summer       0       2018     Summer           0     LowCancClient
#
#      Staff BLastStaff  StaffCancType BLastServiceCode BLastWomenMenService  \
# 0   JOANNE     JOANNE  HighCancStaff              CAL                Other
# 1   JOANNE      BECKY  HighCancStaff             SHCW                Woman
# 2   JOANNE  NewClient  HighCancStaff        NewClient            NewClient
# 3   JOANNE         JJ  HighCancStaff             SHCW                Woman
# 4   JOANNE     JOANNE  HighCancStaff              CAL                Other
# 5   JOANNE         JJ  HighCancStaff             SHCW                Woman
# 6   JOANNE     JOANNE  HighCancStaff              CAL                Other
# 7   JOANNE         JJ  HighCancStaff             SHCM                  Man
# 8   JOANNE     JOANNE  HighCancStaff              CAL                Other
# 9   JOANNE     JOANNE  HighCancStaff            CHLPL                Other
# 10  JOANNE     JOANNE  HighCancStaff            CHLPL                Other
# 11  JOANNE         JJ  HighCancStaff             SHCM                  Man
# 12  JOANNE     JOANNE  HighCancStaff             CALC                Other
# 13  JOANNE         JJ  HighCancStaff             SHCM                  Man
# 14  JOANNE     JOANNE  HighCancStaff             CALC                Other
# 15  JOANNE      KELLY  HighCancStaff              SBD                Other
# 16  JOANNE         JJ  HighCancStaff             SHCW                Woman
# 17  JOANNE     JOANNE  HighCancStaff             CALC                Other
# 18  JOANNE      BECKY  HighCancStaff              SBD                Other
# 19  JOANNE      BECKY  HighCancStaff              SBD                Other
#
#    BLastColorCutService LastServiceCategory ServiceCode ServiceCancType  \
# 0                 Other               COLOR         CAL  LowCancService
# 1                   Cut               STYLE         CAL  LowCancService
# 2             NewClient           NewClient         CAL  LowCancService
# 3                   Cut               STYLE         CAL  LowCancService
# 4                 Other               COLOR         CAL  LowCancService
# 5                   Cut               STYLE         CAL  LowCancService
# 6                 Other               COLOR         CAL  LowCancService
# 7                   Cut               STYLE         CAL  LowCancService
# 8                 Other               COLOR         CAL  LowCancService
# 9                 Other               COLOR         CAL  LowCancService
# 10                Other               COLOR        CALC  LowCancService
# 11                  Cut               STYLE        CALC  LowCancService
# 12                Color               COLOR        CALC  LowCancService
# 13                  Cut               STYLE        CALC  LowCancService
# 14                Color               COLOR        CALC  LowCancService
# 15                Other               STYLE        CALC  LowCancService
# 16                  Cut               STYLE        CALC  LowCancService
# 17                Color               COLOR        CALC  LowCancService
# 18                Other               STYLE        CALC  LowCancService
# 19                Other               STYLE        CALC  LowCancService
#
#    WomenMenService ColorCutService ServiceCategory  ServicePrice  ServiceCost  \
# 0            Other           Other           COLOR           0.0          NaN
# 1            Other           Other           COLOR           0.0          NaN
# 2            Other           Other           COLOR           0.0          NaN
# 3            Other           Other           COLOR           0.0          NaN
# 4            Other           Other           COLOR           0.0          NaN
# 5            Other           Other           COLOR           0.0          NaN
# 6            Other           Other           COLOR           0.0          NaN
# 7            Other           Other           COLOR           0.0          NaN
# 8            Other           Other           COLOR           0.0          NaN
# 9            Other           Other           COLOR           0.0          NaN
# 10           Other           Color           COLOR           0.0          NaN
# 11           Other           Color           COLOR           0.0          NaN
# 12           Other           Color           COLOR           0.0          NaN
# 13           Other           Color           COLOR           0.0          NaN
# 14           Other           Color           COLOR           0.0          NaN
# 15           Other           Color           COLOR           0.0          NaN
# 16           Other           Color           COLOR           0.0          NaN
# 17           Other           Color           COLOR           0.0          NaN
# 18           Other           Color           COLOR           0.0          NaN
# 19           Other           Color           COLOR           0.0          NaN
#
#    IsCanceled LastIsCanceled  TotalClientBookingsTillNow DaysRecency_cat  \
# 0           0              0                         7.0       NewClient
# 1           0              0                         5.0       NewClient
# 2           0      NewClient                         0.0       NewClient
# 3           0              0                         3.0       NewClient
# 4           0              0                         4.0       NewClient
# 5           0              0                         3.0       NewClient
# 6           0              0                         4.0       NewClient
# 7           0              0                         6.0       NewClient
# 8           0              0                         8.0       NewClient
# 9           0              1                         1.0     19.00-50.00
# 10          0              0                         3.0    50.00-260.00
# 11          0              0                        10.0       NewClient
# 12          0              0                        11.0       NewClient
# 13          0              0                         1.0       NewClient
# 14          0              0                         3.0       NewClient
# 15          0              0                         8.0    50.00-260.00
# 16          0              0                         1.0       NewClient
# 17          0              0                         2.0       NewClient
# 18          0              1                        19.0       NewClient
# 19          0              0                        16.0       NewClient
#
#    LastServicePrice_cat LastServiceCost_cat  \
# 0             NewClient          5.00-10.00
# 1           0.00-102.00           0.00-5.00
# 2             NewClient           NewClient
# 3           0.00-102.00           0.00-5.00
# 4             NewClient          5.00-10.00
# 5           0.00-102.00           0.00-5.00
# 6             NewClient          5.00-10.00
# 7             NewClient           0.00-5.00
# 8             NewClient          5.00-10.00
# 9             NewClient          5.00-10.00
# 10            NewClient          5.00-10.00
# 11            NewClient           0.00-5.00
# 12            NewClient          5.00-10.00
# 13            NewClient           0.00-5.00
# 14            NewClient          5.00-10.00
# 15            NewClient           0.00-5.00
# 16          0.00-102.00           0.00-5.00
# 17            NewClient          5.00-10.00
# 18            NewClient           0.00-5.00
# 19            NewClient           0.00-5.00
#
#    TotalClientCancellationsTillNow_cat CancellationPcnt_cat
# 0                            NewClient            NewClient
# 1                            NewClient            NewClient
# 2                            NewClient            NewClient
# 3                            NewClient            NewClient
# 4                            NewClient            NewClient
# 5                            NewClient            NewClient
# 6                            NewClient            NewClient
# 7                            NewClient            NewClient
# 8                            NewClient            NewClient
# 9                            0.00-2.00            0.27-1.00
# 10                           0.00-2.00            0.27-1.00
# 11                           NewClient            NewClient
# 12                           NewClient            NewClient
# 13                           NewClient            NewClient
# 14                           NewClient            NewClient
# 15                           NewClient            NewClient
# 16                           NewClient            NewClient
# 17                           NewClient            NewClient
# 18                           0.00-2.00            0.00-0.27
# 19                           NewClient            NewClient

# %%
msno.matrix(NoShow,figsize=(25,25))

# %% [markdown]
# ### According to this matrix, after the treatments we have performed there are only 2 variables with lots of missings-"ServiceCost", "TotalClientBookingsTillNow" and these are actually our previous outliers.
# ### Treatment: Categorization:

# %%
for column in ["ServiceCost", "TotalClientBookingsTillNow"]:
        num_of_cat = 5
        bins = np.unique([np.quantile(var.dropna(),quantile/num_of_cat) for quantile in range(0,num_of_cat+1)])
        categories = [f'{bins[index]:.2f}-{bins[index+1]:.2f}' for index in range(0,len(bins)-1)]
        NoShow[f'{column}_cat'] = pd.cut(NoShow[column], bins, labels=categories).astype('category')
        if column == "TotalClientBookingsTillNow" :
            NoShow[f'{column}_cat'].cat.add_categories(['NewClient'], inplace=True)
            NoShow[f'{column}_cat'].fillna('NewClient', inplace=True)
        else:
            NoShow[f'{column}_cat'].cat.add_categories(['Unknown'], inplace=True)
            NoShow[f'{column}_cat'].fillna('Unknown', inplace=True)
        NoShow.drop(column, inplace=True, axis=1)

# %%
msno.matrix(NoShow,figsize=(25,25))

# %%
NoShow.to_pickle ('NoShow_Clean.pkl')
